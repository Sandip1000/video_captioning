# %%
from huggingface_hub import upload_folder

upload_folder(
    folder_path="D:/ckpt-nllb-vatex/checkpoint-8000",
    path_in_repo="checkpoint-8000",
    repo_id="Sandip10/tf_qf_nnlb_vatex_train_ckpt",
    repo_type="model"
)
# Out:
# model.safetensors:   0%|          | 0.00/6.37G [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# rng_state.pth:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# optimizer.pt:   0%|          | 0.00/4.58G [00:00<?, ?B/s]
# scaler.pt:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# scheduler.pt:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Sandip10/tf_qf_nnlb_vatex_train_ckpt/commit/8130ab1e4f34246e115d030de1b7d47a0449f309', commit_message='Upload folder using huggingface_hub', commit_description='', oid='8130ab1e4f34246e115d030de1b7d47a0449f309', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Sandip10/tf_qf_nnlb_vatex_train_ckpt', endpoint='https://huggingface.co', repo_type='model', repo_id='Sandip10/tf_qf_nnlb_vatex_train_ckpt'), pr_revision=None, pr_num=None)
